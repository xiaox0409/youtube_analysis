# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
comments = pd.read_csv(r'/Users/xiao/Downloads/data project/Youtube_project_shan_singh_Udemy/UScomments.csv' , on_bad_lines='skip')
# Out:
# /var/folders/hm/myxdjkbj4m72k1qm3y62ky5h0000gn/T/ipykernel_36137/3568770525.py:1: DtypeWarning: Columns (2,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   comments = pd.read_csv(r'/Users/xiao/Downloads/data project/Youtube_project_shan_singh_Udemy/UScomments.csv' , on_bad_lines='skip')

# %%
comments.head()
# Out:
#       video_id                                       comment_text likes  \
# 0  XpVt6Z1Gjjo                  Logan Paul it's yo big day ‼️‼️‼️     4
# 1  XpVt6Z1Gjjo  I've been following you from the start of your...     3
# 2  XpVt6Z1Gjjo                 Say hi to Kong and maverick for me     3
# 3  XpVt6Z1Gjjo                                MY FAN . attendance     3
# 4  XpVt6Z1Gjjo                                         trending 😉     3
#
#   replies
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
comments.dropna(inplace=True)

# %%
# !pip install textblob
# !pip install wordcloud

# %%
from textblob import TextBlob

# %%
polarity = []
for comment in comments['comment_text']:
    try:
        polarity.append(TextBlob(comment).sentiment.polarity)
    except:
        polarity.append(0)

# %%
comments['polarity'] = polarity

# %%
positive_comments = comments[comments['polarity'] == 1]
negative_comments = comments[comments['polarity'] == -1]

# %%
total_positive_comments =' '.join(positive_comments['comment_text'])
total_negative_comments =' '.join(negative_comments['comment_text'])

# %%
from wordcloud import WordCloud, STOPWORDS
wordcloud = WordCloud(stopwords=set(STOPWORDS)).generate(total_positive_comments)
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
from wordcloud import WordCloud, STOPWORDS
wordcloud = WordCloud(stopwords=set(STOPWORDS)).generate(total_negative_comments)
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)
